# %%
pip install -e /home/calisto/github/settling_in_space/src
# Out:
# Obtaining file:///home/calisto/github/settling_in_space/src
# Installing collected packages: settlingInSpace
#   Running setup.py develop for settlingInSpace
# Successfully installed settlingInSpace
# Note: you may need to restart the kernel to use updated packages.

# %%
from settlingInSpace.game.main import SettlingMain

main = SettlingMain()
main.interface.configure()
main.interface.initialize()
main.interface.start()

# %%
for name in main.game_engine.gamemodel.:
    print(name)

# %%
for star in main.game_engine.gamemodel.dict_starsystems:
    print("{0}: {1}".format(star, main.game_engine.gamemodel.dict_starsystems[star].position))
# Out:
# Rastaban: [183  85 177]
# Secunda Hyadum: [160  47 184]
# Hatysa: [ 58 125 135]
# Kang: [122 111 193]
# Regulus: [ 84 130 130]
# Ascella: [145 147 106]
# Aladfar: [101 154 106]
# Rasalhague: [ 63 129 124]
# Uruk: [ 21  54 154]
# Celaeno: [108  81 165]
# Kakkab: [145 103 129]
# Syrma: [ 74 105 189]
# Wasat: [145  26 190]
# Tangra: [ 71   5 163]
# Tania Australis: [188 126 132]
# Fomalhaut: [ 82 175 193]
# Cervantes: [120 127 161]
# Dalim: [ 97   9 174]
# Muscida: [144  45 185]
# Alcor: [168  43 136]
# Intan: [163 106 114]
# Nekkar: [101   6 102]
# Segin: [112 191 127]
# Bunda: [ 29  98 140]
# Mimosa: [ 45 107 143]
# Gienah: [146 166 129]
# Sterrennacht: [ 52 141 175]
# Bellatrix: [ 47  47 180]
# Mirzam: [ 60  50 119]
# Tapecue: [ 14 134 105]
# Ginan: [137 190 191]
# Mirfak: [167  88 169]
# Duwo: [149 125 194]
# Pipirima: [106 168 153]
# Regor: [ 56 160 115]
# Libertas: [ 31 134 106]
# Naledi: [ 78  87 164]
# Nushagak: [ 67 155 188]
# Larawag: [154 179 183]
# Tianguan: [143 125 123]

# %%
for star in main.game_engine.gamemodel.dict_starsystems:
    print("star {0}: {1}".format(star, main.game_engine.gamemodel.dict_starsystems[star].position))
    for obj in main.game_engine.gamemodel.dict_starsystems[star].list_system_objects:
        print("object {0}".format(obj.name))

# %%
obj = main.game_engine.gamemodel.dict_starsystems['Rastaban'].list_system_objects[0]
print("{0}: {1},{2},{3}".format(obj.name, obj.position, obj.angle, obj.speed))
# Out:
# Alupka: [ 8.11964207e+03 -1.99000643e+02 -2.78258375e-01],119.01379627500626,0.00011496895838123707

# %%
from random import Random

for i in range(0,40):
    _random = Random()
    print(_random.randrange(4,12))

# %%
for name in main.game_engine.gamemodel.starsystemnames:
    print(name)

# %%
import numpy
numpy.random.normal(0.0, 100.0, 100)

# %%
import numpy as geek 
import matplotlib.pyplot as plot 
   
# 1D Array as per Gaussian Distribution 
mean = 0 
std = 0.1
array = geek.random.normal(0, 0.1, 100)

# %%
# Source Code :  
# https://docs.scipy.org/doc/numpy-1.13.0/reference/ 
# generated/numpy-random-normal-1.py 
count, bins, ignored = plot.hist(array, 60) 
plot.plot(bins, 1/(std * geek.sqrt(2 * geek.pi)) *
          geek.exp( - (bins - mean)**2 / (2 * std**2) ), 
          linewidth=2, color='r') 
plot.show()

# %%
for i in range(-50,50):
    j = i/100
    print(1/(std * geek.sqrt(2 * geek.pi)) *
          geek.exp( - (j - mean)**2 / (2 * std**2) ))

# %%
import numpy as geek 
import matplotlib.pyplot as plot 
   
# 1D Array as per Gaussian Distribution 
mean = 6
std = 10
array = geek.random.normal(6, 3.0, 40)
for i in range(0,40):
    value = int(array[i])
    if value < 3 or value > 12:
        value = 6
    print(value)
    array[i] = value
# Source Code :  
# https://docs.scipy.org/doc/numpy-1.13.0/reference/ 
# generated/numpy-random-normal-1.py 
count, bins, ignored = plot.hist(array, 60)
plot.plot(bins, 1/(std * geek.sqrt(2 * geek.pi)) *
          geek.exp( - (bins - mean)**2 / (2 * std**2) ), 
          linewidth=2, color='r') 
plot.show()

# %%
import numpy
(numpy.random.random(12)*10000).astype(numpy.int64)
# Out:
# array([6434, 6012, 5457, 7058, 5246, 2773, 8296, 4270, 3265, 1622, 3848,
#         344])

# %%
import tkinter as tk

# %%
import scipy

# %%
pip list
# Out:
# Package            Version             Location
# ------------------ ------------------- ------------------------------------------
# attrs              19.3.0
# backcall           0.1.0
# bleach             3.1.4
# certifi            2020.4.5.1
# custommagics       0.0.1
# cycler             0.10.0
# decorator          4.4.2
# defusedxml         0.6.0
# entrypoints        0.3
# graphviz           0.13.2
# importlib-metadata 1.6.0
# ipykernel          5.2.1
# ipympl             0.5.6
# ipython            7.13.0
# ipython-genutils   0.2.0
# ipywidgets         7.5.1
# jedi               0.17.0
# Jinja2             2.11.2
# json5              0.9.4
# jsonschema         3.2.0
# jupyter-client     6.1.3
# jupyter-core       4.6.3
# jupyterlab         1.2.7
# jupyterlab-server  1.0.7
# kiwisolver         1.2.0
# MarkupSafe         1.1.1
# matplotlib         3.2.1
# mistune            0.8.4
# more-itertools     8.2.0
# nbconvert          5.6.1
# nbformat           5.0.5
# notebook           6.0.3
# numpy              1.18.2
# packaging          20.3
# pandocfilters      1.4.2
# parso              0.7.0
# pexpect            4.8.0
# pickleshare        0.7.5
# pip                20.0.2
# pluggy             0.13.1
# prometheus-client  0.7.1
# prompt-toolkit     3.0.5
# ptyprocess         0.6.0
# py                 1.8.1
# Pygments           2.6.1
# pyparsing          2.4.7
# pyrsistent         0.16.0
# pytest             5.4.1
# python-dateutil    2.8.1
# PyYAML             5.3.1
# pyzmq              19.0.0
# scipy              1.4.1
# Send2Trash         1.5.0
# settlingInSpace    0.0.1               /home/calisto/github/settling_in_space/src
# setuptools         46.1.3.post20200330
# six                1.14.0
# terminado          0.8.3
# testpath           0.4.4
# tornado            6.0.4
# traitlets          4.3.3
# wcwidth            0.1.9
# webencodings       0.5.1
# wheel              0.34.2
# widgetsnbextension 3.5.1
# zipp               3.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import xmlrpc.client

with xmlrpc.client.ServerProxy("http://rpcgame:8088") as proxy:
    # Print list of available methods
    #print(proxy.system.listMethods())
    proxy.restart_gameserver()

# %%
import xmlrpc.client

with xmlrpc.client.ServerProxy("http://rpcgame:8082") as proxy:
    # Print list of available methods
    print(proxy.system.listMethods())
    print(proxy.getStarSystemsDictStatic())
    #proxy.restart_gameserver()
# Out:
# ['configure', 'getStarSystemsDictStatic', 'initialize', 'start', 'system.listMethods', 'system.methodHelp', 'system.methodSignature']
# {'Deneb Algedi': ['Wongshingsheuk', 'Ianmorison', 'Maclaurin'], 'Baten Kaitos': ['Stephencolbert', 'Davisdon', 'Dorffel'], 'Talitha': ['Alainmilsztajn', 'Deringer', 'Tukmit', 'Meyermann'], 'Sadalbari': ['Degraaff', 'Kabos', 'Kangsunwoo', 'Edmee', 'Mindaugas', 'Dorothynorton', 'Arhale'], 'Adhafera': ['Deslorieux', 'Bamberga', 'Mikula', 'Nonna', 'Lanthrum'], 'Brachium': ['Messalina', 'Minor', 'Frankiethomas', 'Grieg', 'Zibiturtle', 'Aalamiharandi', 'Nadiavittor'], 'Tarf': ['Dianaeheart', 'Andreacamilleri', 'Lappajarvi', 'Golgi', 'Ilos'], 'Alsafi': ['Aleserpieri', 'Delores', 'Iduna', 'Tongjili', 'Penghuanwu', 'Leget', 'Saltzman'], 'Angetenar': ['Dirikis', 'Almamater', 'Hughsavoldelli', 'Warmuth'], 'Atria': ["d'Auteroche", 'Bouillabaisse', 'Lysippus', 'Chern'], 'Alathfar': ['Aivazovskij', 'Musunuri', 'Volpe', 'Burt', 'Yukifumi', 'Skrutskie'], 'Sharjah': ['Kurtschreckling', 'Clarissa', 'Takane', 'Langberg', 'Chisholm', 'Spinrad', 'Ilias'], 'Xuange': ['Eduardoröhl', 'Rogerwaters', 'Crampton'], 'Miaplacidus': ['Hosinokokai', 'Vorperian', 'Kirkpatrick', 'McDonnell'], 'La Superba': ['Thelonious', 'Almeida', 'Wagner', 'Anabuki', 'Azusagawa', 'Johngenereid'], 'Chaophraya': ['Kalman', 'Takeyamamoto', 'Marietta', 'Myriostos'], 'Lerna': ['Aprillee', 'Satoshi', 'Uemuraikuo', 'Breimer', 'Matterania', 'Danielhals', 'Bajin', 'Lusigny', 'Aiweiwei'], 'Sheratan': ['Vorosmarty', 'Dewaldroode', 'Jayardee', 'Barks', 'Jayewinkler', 'Poltava', 'Katiedavis', 'Yamatenclub', 'Wu Chien-Shiung', 'Aizuyaichi'], 'Kuma': ['Van Dijck', 'Yaoskalucia', 'Josephnuth', 'Romulus', 'Constable', 'Kenglover', 'Asterix', 'Danieldrinnon', 'Saraburger', 'Katherinewu', 'Kita-Kyushu'], 'Dubhe': ['Astapovich', 'Madenberg', 'Zeljkoandreic', 'Haolei', 'Beslan', 'Hachioji', 'Paulmyers'], 'Ayeyarwady': ['Naudts', 'Alps', 'Ottegebe', 'Vasifedoseev'], 'Regor': ['Caz', 'Stephwerner', 'Ballmann', 'Dzhanibekov', 'Pratchett', 'Ewen'], 'Sarir': ['Thales', 'Yoshitsune', 'Folco', 'Sarastro', 'Sarasakowitz', 'Mossotti', 'Imhotep'], 'Macondo': ['Hideosugai', 'Bahuffman', 'Loriharrison', 'Alexgreaves'], 'Atik': ['Borngen', 'Fatme', 'Brehm', 'Edshay'], 'Atakoraka': ['Shurpakov', 'Shandroff', 'Underwood', 'Bruna', 'Johnharvey', 'Shimizuyuka', 'Garyross', 'Lausanna'], 'Scheat': ['Philaret', 'Urakawa', 'Delgordon', 'Angola', 'Maironis', 'Daassou', 'Illyria', 'Hundertwasser', 'Helenejacq'], 'Acubens': ['Madreteresa', 'Shinseiko', 'Eskow', 'Clymene', 'Shisseh', 'Rimavská Sobota', 'Saxogrammaticus', 'Meadows', 'Bertola'], 'Polis': ['Irsha', 'Barto', 'Sariancel'], 'Acrab': ['Pullen', 'Johnbackus', 'Taitung', 'Cybele', 'Videen', 'Wallin'], 'Ainalrami': ['Solc', 'Jenikhollan', 'Noctua', 'Callander', 'Kevingarbe', 'Matson'], 'Tangra': ['Marhalpern', 'Shigenari', 'Antonalexander', 'Hidatakayama', 'Susanstern', 'Shinsaku'], 'Montuno': ['Schober', 'Tylerlinder', 'Sielmann', 'Blaschke', 'Leoconnolly', 'Sakamoto'], 'Iklil': ['Wenyucao', 'Kochte', 'Sebastien', 'Ladányi', 'Alfaterna', 'Noradokei', 'Sandrine', 'Suvanto', 'Gardenia'], 'Cervantes': ['Rhondah', 'Donnajones', 'Calbuco', 'Jessedouglas', 'Donalek', 'Mykolapokropyvny'], 'Aldhibah': ['Gaywray', 'Ullmann', 'Mizuho', 'Masayanagisawa', 'Alfredmaria', 'Viviantsang'], 'Kekouan': ['Dionysus', 'Cornus', 'Kevlin'], 'Duwo': ['Byrd', 'Fagnes', 'Kabinoff'], 'Sagarmatha': ['Meucci', 'Mors-Somnus', 'Wolfgangries', 'Buxus', 'Imperatrix'], 'Yildun': ['Johnbarnes', 'Nyrola', 'Jennipolakis', 'Echemmon', 'Urriellu', 'Itomori']}

# %%
pip install geom3
# Out:
# ERROR: Could not find a version that satisfies the requirement geom3 (from versions: none)
# ERROR: No matching distribution found for geom3
# Note: you may need to restart the kernel to use updated packages.

# %%
from geom3 import Vector3, Point3, Ray3, dot, unit
from math import sqrt
from hit import Hit
#https://github.com/phire/Python-Ray-tracer/blob/master/sphere.py
        """The ray t value of the first intersection point of the
        ray with self, or None if no intersection occurs"""
        hit = None
        q = self.centre - ray.start
        vDotQ = dot(ray.dir, q)
        squareDiffs = dot(q, q) - self.radius*self.radius
        discrim = vDotQ * vDotQ - squareDiffs
        if discrim >= 0:
            root = sqrt(discrim)
            t0 = (vDotQ - root)
            t1 = (vDotQ + root)
            if t0 < t1:
                hit = Hit(self, ray, t0, t1, None, self.material)
            else:
                hit = Hit(self, ray, t1, t0, None, self.material)
            if hit.entry > 0:
                hit.normal = self.normal(ray.pos(hit.entry))
            if hit.exit > 0:
                hit.normal2 = self.normal(ray.pos(hit.exit))
        return hit

# %%
import numpy

hit = None
# sphere def
sphere_centre = numpy.array([1,1,1])
sphere_radius = 1

# ray def
ray_point = numpy.array([1,10,1])
ray_dir = numpy.array([2,10,1])

q = sphere_centre - ray_point
print(q)
vDotQ = numpy.dot(ray_dir, q)
print(vDotQ)
squareDiffs = numpy.dot(q,q) - sphere_radius*sphere_radius
print( numpy.dot(q,q))
discrim = vDotQ*vDotQ - squareDiffs
if discrim >= 0:
    root = numpy.sqrt(discrim)
    t0 = (vDotQ - root)
    t1 = (vDotQ + root)
    if t0 < t1:
        print('t0 < t1: {0} {1}'.format(t0,t1))
    else:
        print('else: {0} {1}'.format(t0,t1))
else:
    print('none')
# Out:
# [ 0 -9  0]
# -90
# 81
# t0 < t1: -179.55445270895245 -0.44554729104756063

# %%
import numpy

numpy.dot(numpy.array([1,2,3]), numpy.array([]))
# Out:
# 36

# %%
# http://viclw17.github.io/2018/07/16/raytracing-ray-sphere-intersection/
bool hit_sphere(const vec3& center, float radius, const ray& r){
    vec3 oc = r.origin() - center;
    float a = dot(r.direction(), r.direction());
    float b = 2.0 * dot(oc, r.direction());
    float c = dot(oc,oc) - radius*radius;
    float discriminant = b*b - 4*a*c;
    return (discriminant>0);
}

float hit_sphere(const vec3& center, float radius, const ray& r){
    vec3 oc = r.origin() - center;
    float a = dot(r.direction(), r.direction());
    float b = 2.0 * dot(oc, r.direction());
    float c = dot(oc,oc) - radius*radius;
    float discriminant = b*b - 4*a*c;
    if(discriminant < 0){
        return -1.0;
    }
    else{
        return (-b - sqrt(discriminant)) / (2.0*a);
    }
}

# %%
# adapt from http://viclw17.github.io/2018/07/16/raytracing-ray-sphere-intersection/
import numpy

# sphere def
sphere_centre = numpy.array([1,1,1])
sphere_radius = 1

# ray def
ray_point = numpy.array([1,10,1])
ray_dir = numpy.array([0,1,0])

unit = numpy.ones(3)

oc = ray_point - sphere_centre
a = numpy.dot(ray_dir, ray_dir)
b = 2 * numpy.dot(oc, ray_dir)
c = numpy.dot(oc, oc) - sphere_radius*sphere_radius
discrim = b*b - 4*a*c

if discrim > 0:
    print('solution exists')
    square_root = numpy.sqrt(discrim)
    t0 = (-b - square_root) / (2*a)
    t1 = (-b + square_root) / (2*a)
    print(t0)
    print(t1)
else:
    print('no solution exists')
# Out:
# solution exists
# -10.0
# -8.0

# %%
import numpy

# sphere def
sphere_centre = numpy.array([1,1,1])
sphere_radius = 1

# ray def
ray_point = numpy.array([1,10,1])
ray_dir = numpy.array([0,1,0])

point = ray_point + ray_dir*(-8)

print(point)
# Out:
# [1 2 1]

# %%
def calc_intersect(ray_point, ray_dir, sphere_centre, sphere_radius):
    print('{0} {1} {2} {3}'.format(ray_point, ray_dir, sphere_centre, sphere_radius))
    unit = numpy.ones(3)

    oc = ray_point - sphere_centre
    a = numpy.dot(ray_dir, ray_dir)
    b = 2 * numpy.dot(oc, ray_dir)
    c = numpy.dot(oc, oc) - sphere_radius*sphere_radius
    discrim = b*b - 4*a*c

    if discrim > 0:
        print('solution exists')
        square_root = numpy.sqrt(discrim)
        t0 = (-b - square_root) / (2*a)
        t1 = (-b + square_root) / (2*a)
        if t0 < t1:
            return t0
        else:
            return t1
    else:
        print('no solution exists')

# %%
# https://www.forum-marinearchiv.de/smf/index.php?topic=27157.0
# https://www.codefull.net/2015/06/intersection-of-a-ray-and-a-line-segment-in-3d/
# https://gist.github.com/danieljfarrell/faf7c4cafd683db13cbc
# https://stackoverflow.com/questions/2316490/the-algorithm-to-find-the-point-of-intersection-of-two-3d-line-segment
# 
import numpy
e_pos = numpy.array([1,1,1])
e_dir = numpy.array([0,1,0])
e_speed = 1

s_pos = numpy.array([5,1,1])
s_speed = 2

e_s_pre = e_pos - s_pos
e_s = 1/numpy.linalg.norm(e_s_pre)*e_s_pre

e_pos1 = e_pos + e_speed*e_dir

dist = calc_intersect(e_pos1,e_s,s_pos,s_speed)

sphere_point = e_pos1 + dist*e_s

s_dir_pre = sphere_point - s_pos
s_dir = 1/numpy.linalg.norm(s_dir_pre) * s_dir_pre

for i in range(1,20):
    e_point = e_pos + e_dir*i*e_speed
    s_point = s_pos + s_dir*i*-s_speed
    print(e_point)
    print(s_point)
# Out:
# [1 2 1] [-1.  0.  0.] [5 1 1] 2
# solution exists
# [1 2 1]
# [ 3.26794919e+00 -2.22044605e-16  1.00000000e+00]
# [1 3 1]
# [ 1.53589838 -1.          1.        ]
# [1 4 1]
# [-0.19615242 -2.          1.        ]
# [1 5 1]
# [-1.92820323 -3.          1.        ]
# [1 6 1]
# [-3.66025404 -4.          1.        ]
# [1 7 1]
# [-5.39230485 -5.          1.        ]
# [1 8 1]
# [-7.12435565 -6.          1.        ]
# [1 9 1]
# [-8.85640646 -7.          1.        ]
# [ 1 10  1]
# [-10.58845727  -8.           1.        ]
# [ 1 11  1]
# [-12.32050808  -9.           1.        ]
# [ 1 12  1]
# [-14.05255888 -10.           1.        ]
# [ 1 13  1]
# [-15.78460969 -11.           1.        ]
# [ 1 14  1]
# [-17.5166605 -12.          1.       ]
# [ 1 15  1]
# [-19.24871131 -13.           1.        ]
# [ 1 16  1]
# [-20.98076211 -14.           1.        ]
# [ 1 17  1]
# [-22.71281292 -15.           1.        ]
# [ 1 18  1]
# [-24.44486373 -16.           1.        ]
# [ 1 19  1]
# [-26.17691454 -17.           1.        ]
# [ 1 20  1]
# [-27.90896534 -18.           1.        ]

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.0.3-cp37-cp37m-manylinux1_x86_64.whl (10.0 MB)
#      |████████████████████████████████| 10.0 MB 238 kB/s eta 0:00:01    |████████▊                       | 2.7 MB 1.6 MB/s eta 0:00:05     |████████████▍                   | 3.9 MB 615 kB/s eta 0:00:11     |███████████████▍                | 4.8 MB 615 kB/s eta 0:00:09     |█████████████████▎              | 5.4 MB 1.8 MB/s eta 0:00:03     |███████████████████████████▏    | 8.5 MB 919 kB/s eta 0:00:02     |████████████████████████████▌   | 8.9 MB 1.4 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.6.1 in /app/jupyter/lib/python3.7/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.13.3 in /app/jupyter/lib/python3.7/site-packages (from pandas) (1.18.4)
# Collecting pytz>=2017.2
#   Downloading pytz-2020.1-py2.py3-none-any.whl (510 kB)
#      |████████████████████████████████| 510 kB 1.4 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in /app/jupyter/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas) (1.14.0)
# Installing collected packages: pytz, pandas
# Successfully installed pandas-1.0.3 pytz-2020.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
lst = [[12,34,23,'a'],[23,34,67,'b'],[47,53,28,'c']]
df = pd.DataFrame(lst, columns =['x', 'y', 'z', 'name'])
df
# Out:
#     x   y   z name
# 0  12  34  23    a
# 1  23  34  67    b
# 2  47  53  28    c

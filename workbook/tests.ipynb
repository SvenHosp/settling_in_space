# %%
pip install -e /home/calisto/github/settling_in_space/src
# Out:
# Obtaining file:///home/calisto/github/settling_in_space/src
# Installing collected packages: settlingInSpace
#   Attempting uninstall: settlingInSpace
#     Found existing installation: settlingInSpace 0.0.1
#     Uninstalling settlingInSpace-0.0.1:
#       Successfully uninstalled settlingInSpace-0.0.1
#   Running setup.py develop for settlingInSpace
# Successfully installed settlingInSpace
# Note: you may need to restart the kernel to use updated packages.

# %%
from settlingInSpace.game.main import SettlingMain

main = SettlingMain()
main.configure()
main.initialize()
main.start()

# %%
for name in main.game_engine.list_starnames:
    print(name)

# %%
for star in main.game_engine.gamemodel.dict_starsystems:
    print("{0}: {1}".format(star, main.game_engine.gamemodel.dict_starsystems[star].position))
# Out:
# Kaus Borealis: [ 82  61 151]
# Aljanah: [ 12  81 168]
# Caph: [ 25 122 160]
# Tonatiuh: [ 84 193 127]
# Tevel: [ 16  46 197]
# Ain: [ 39  32 150]
# Alkarab: [169  90 123]
# Albali: [ 99 122 179]
# Dziban: [145  99 112]
# Sterrennacht: [ 60 132 164]
# Brachium: [ 80 172 152]
# Segin: [ 27 145 135]
# Adhil: [141 173 150]
# Misam: [ 61 100 178]
# Tarf: [181  93 183]
# Bunda: [ 37 153 180]
# Alnair: [  3  92 166]
# Sadr: [103 172 121]
# Kuma: [170  76 169]
# Larawag: [ 51 155 171]
# Alshain: [ 40  56 159]
# Minelauva: [ 22  50 118]
# Emiw: [ 78 138 114]
# Propus: [ 86 168 197]
# Nihal: [192 135 173]
# Alrescha: [114  79 184]
# Beemim: [ 26 131 130]
# Berehinya: [ 21  75 100]
# Syrma: [ 82 118 127]
# Fomalhaut: [193  87 132]
# Intercrus: [ 97 186 144]
# Tojil: [ 67 167 116]
# Achird: [ 83  41 105]
# Tangra: [ 45 108 115]
# Alnilam: [ 60 112 196]
# Mouhoun: [ 98  26 199]
# Kitalpha: [104  70 166]
# Menkalinan: [170 162 195]
# Petra: [ 37 140 178]
# Alathfar: [ 77 112 136]

# %%
from random import Random

_random = Random()
_random.randrange(100)
# Out:
# 84

# %%
pip install -e /home/calisto/github/settling_in_space/src
# Out:
# Obtaining file:///home/calisto/github/settling_in_space/src
# Installing collected packages: settlingInSpace
#   Attempting uninstall: settlingInSpace
#     Found existing installation: settlingInSpace 0.0.1
#     Uninstalling settlingInSpace-0.0.1:
#       Successfully uninstalled settlingInSpace-0.0.1
#   Running setup.py develop for settlingInSpace
# Successfully installed settlingInSpace
# Note: you may need to restart the kernel to use updated packages.

# %%
from settlingInSpace.game.main import SettlingMain

main = SettlingMain()
main.start()

# %%
for star in main.game_engine.gamemodel.list_starsystems:
    print(str(star.x) + "," + str(star.y) + "," + str(star.z) )
# Out:
# 72,166,193
# 39,161,167
# 24,104,180
# 93,184,181
# 44,51,103
# 173,115,139
# 34,172,185
# 131,153,144
# 78,77,107
# 123,101,147
# 70,165,130
# 155,52,142
# 69,57,182
# 175,71,108
# 92,73,196
# 156,22,132
# 58,142,186
# 79,125,142
# 120,113,103
# 46,17,173
# 93,119,118
# 116,151,167
# 142,148,164
# 78,38,152
# 70,47,152
# 19,125,109
# 137,111,123
# 114,53,112
# 86,27,143
# 132,117,196
# 86,170,130
# 115,189,131
# 28,155,180
# 23,98,173
# 160,58,149
# 20,40,108
# 47,38,155
# 156,125,150
# 80,96,114
# 23,43,117

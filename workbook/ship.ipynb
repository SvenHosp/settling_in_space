# %% [markdown]
# # StarShips

# %% [markdown]
# Types of ships:
#
#     * cargo
#     * scout
#     * multi mission (exploration, diplomaty, battle)
#     * colony
#     * war ships

# %% [markdown]
# ships are using impulse drive to travel in star systems and warp drive between star systems.

# %%
# %%plantuml
#
# @startuml
# class ship
# class ship_logic
#
# ship *-- ship_logic
# @enduml

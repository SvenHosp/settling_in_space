# %% [markdown]
# # Treading

# %%
import threading

def worker(num):
    """thread worker function"""
    print('Worker: %s' % num)
    return

threads = []
for i in range(5):
    t = threading.Thread(target=worker, args=(i,))
    threads.append(t)
    t.start()
# Out:
# Worker: 0
# Worker: 1
# Worker: 2
# Worker: 3
# Worker: 4

# %%
import threading

def worker():
    """thread worker function"""
    print('Worker: %s' % num)
    return


num = 10

t = threading.Thread(target=worker)
t.start()
# Out:
# Worker: 10

# %%
import threading
import time

heartbeat_sec = 1

def game_logic():
    # code to execute logic
    pass

def heartbeat():
    print('heartbeat')
    game_logic()
    time.sleep(heartbeat_sec)
    heartbeat_t = threading.Thread(name='heartbeat_t', target=heartbeat)
    heartbeat_t.start()

def game_start():
    heartbeat_t = threading.Thread(name='heartbeat_t', target=heartbeat)
    heartbeat_t.start()

game_start()
# Out:
# heartbeat
# heartbeat
# heartbeat
# heartbeat
# heartbeat
# heartbeat
# heartbeat
# heartbeat
